# %%
import sys
sys.path.append('../../')

import estraces
import scared
import matplotlib.pyplot as plt
from kresca.plot import CurvePlot
from kresca.synchronization import PatternSynchronization

# %% [markdown]
# ## Import Traces

# %%
ths = estraces.read_ths_from_ets_file('../../Traces/AES_CW_60k_unsync.ets')

# %%
print(ths)
# Out:
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file ../../Traces/AES_CW_60k_unsync.ets with 60000 traces.
# key..............: uint8
# plaintext........: uint8

# %% [markdown]
# ## Curve Plot

# %%
#put inline=True if you want to display on notebook
CurvePlot(ths.samples[:5], inline=True)
# Out:
# RFBOutputContext()
# CanvasBackend(css_height='500px', css_width='950px')

# %% [markdown]
# ## Make a Pattern

# %%
start_pattern = 350
end_pattern = 600
reference_trace = 0
pattern = ths[reference_trace].samples[start_pattern:end_pattern]

# %%
plt.figure(figsize=(16, 6))
plt.plot(ths[reference_trace].samples, label='reference trace')
plt.plot(range(start_pattern, end_pattern), pattern, color='orange', label='pattern')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Pattern Synchronization

# %%
example = PatternSynchronization(
    ths=ths,
    patterns=[pattern],
    score_limit=0.5
)

# %%
example.check()

# %%
example.run("example.ets")
# Out:
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Processed traces....: 60000
# Synchronized traces.: 59967
# Success rate........: 99.94%
